# %%
import numpy as np
import pandas as pd

# %%
TD = pd.read_csv(r"C:\Users\rpaul\Downloads\archive\Titanic-Dataset.csv")

# %%
TD
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
TD.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
TD.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
TD.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
TD.shape
# Out:
# (891, 12)

# %%
TD[TD["Age"].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
687/891*100
# Out:
# 77.10437710437711

# %%
TD["Cabin"].nunique()
# Out:
# 147

# %%
TD['Age'].hist(bins=30)
plt.title('Distribution of Age')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
TD['Cabin'].value_counts()
TD['Cabin'].value_counts().plot(kind='bar')
plt.title('Distribution of Cabin')
plt.xlabel('Category')
plt.ylabel('Count')
plt.show()

# %%
TD['Age_pp']= TD['Age'].fillna(TD['Age'].median())

# %%
TD
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(strategy='most_frequent')
TD['Cabin']= imputer.fit_transform(TD[['Cabin']])[:,0]

# %%
TD
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
TD = TD.drop(['Age','Cabin'], axis=1)

# %%
TD
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
TD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Ticket       891 non-null    object
#  8   Fare         891 non-null    float64
#  9   Embarked     889 non-null    object
#  10  Age_pp       891 non-null    float64
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
TD['Embarked'].nunique()
# Out:
# 3

# %%
TD['Sex'] = TD['Sex'].map({'male': 0, 'female': 1})

# %%
TD
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1      1      0
# 2                               Heikkinen, Miss. Laina    1      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1      1      0
# 4                             Allen, Mr. William Henry    0      0      0
# ..                                                 ...  ...    ...    ...
# ...

# %%
imputer=SimpleImputer(strategy='most_frequent')
TD['Embarked']= imputer.fit_transform(TD[['Embarked']])[:,0]

# %%
TD
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1      1      0
# 2                               Heikkinen, Miss. Laina    1      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1      1      0
# 4                             Allen, Mr. William Henry    0      0      0
# ..                                                 ...  ...    ...    ...
# ...

# %%
TD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    int64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Ticket       891 non-null    object
#  8   Fare         891 non-null    float64
#  9   Embarked     891 non-null    object
#  10  Age_pp       891 non-null    float64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 76.7+ KB

# %%
dummies = pd.get_dummies(TD['Embarked'], drop_first=True).astype(int)
TD = pd.concat([TD.drop('Embarked', axis=1), dummies], axis=1)

# %%
TD = TD.drop(['Name','Ticket'],axis=1)

# %%
TD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Sex          891 non-null    int64
#  4   SibSp        891 non-null    int64
#  5   Parch        891 non-null    int64
#  6   Fare         891 non-null    float64
#  7   Age_pp       891 non-null    float64
#  8   Q            891 non-null    int32
#  9   S            891 non-null    int32
# dtypes: float64(2), int32(2), int64(6)
# memory usage: 62.8 KB

# %%
from sklearn.preprocessing import MinMaxScaler
scaler= MinMaxScaler()
TD = scaler.fit_transform(TD)

# %%
TD
# Out:
# array([[0.        , 0.        , 1.        , ..., 0.27117366, 0.        ,
#         1.        ],
#        [0.0011236 , 1.        , 0.        , ..., 0.4722292 , 0.        ,
#         0.        ],
#        [0.00224719, 1.        , 1.        , ..., 0.32143755, 0.        ,
#         1.        ],
#        ...,
#        [0.99775281, 0.        , 1.        , ..., 0.34656949, 0.        ,
#         1.        ],
#        [0.9988764 , 1.        , 0.        , ..., 0.32143755, 0.        ,
#         0.        ],
#        [1.        , 0.        , 1.        , ..., 0.39683338, 1.        ,
#         0.        ]])
